# %%
import pandas as pd 
import numpy as np
import scipy.stats as scs
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
food = pd.read_csv('nutritional_data.csv')
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
food.head()
# Out:
#       code                       product_name          brands origins  \
# 0   4530.0     Banana Chips Sweetened (Whole)             NaN     NaN
# 1   4559.0                            Peanuts  Torn & Glasser     NaN
# 2  16087.0             Organic Salted Nut Mix       Grizzlies     NaN
# 3  16094.0                    Organic Polenta  Bob's Red Mill     NaN
# 4  16100.0  Breadshop Honey Gone Nuts Granola            Unfi     NaN
#
#    calories_pg  fat_pg  carbs_pg  proteins_pg  sodium_pg  \
# 0     5.360905  0.2857    0.6429       0.0357    0.00000
# 1     4.639106  0.1786    0.6071       0.1786    0.00250
# 2     6.070752  0.5714    0.1786       0.1786    0.00482
# 3     3.709373  0.0143    0.7714       0.0857        NaN
# 4     4.619986  0.1827    0.6346       0.1346        NaN
#
#    nutrition-score-uk_100g
# 0                     14.0
# 1                      0.0
# 2                     12.0
# 3                      NaN
# 4                      NaN

# %%
food = food.fillna(0)

# %%
servings = pd.read_csv('data_with_serving_sizes.csv')
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
servings.head()
# Out:
#       code                       product_name          brands origins  \
# 0   4530.0     Banana Chips Sweetened (Whole)               0       0
# 1   4559.0                            Peanuts  Torn & Glasser       0
# 2  16087.0             Organic Salted Nut Mix       Grizzlies       0
# 3  16094.0                    Organic Polenta  Bob's Red Mill       0
# 4  16100.0  Breadshop Honey Gone Nuts Granola            Unfi       0
#
#    calories_pg  fat_pg  carbs_pg  proteins_pg  sodium_pg     serving_size  \
# 0     5.360905  0.2857    0.6429       0.0357    0.00000     28 g (1 ONZ)
# 1     4.639106  0.1786    0.6071       0.1786    0.00250  28 g (0.25 cup)
# 2     6.070752  0.5714    0.1786       0.1786    0.00482  28 g (0.25 cup)
# 3     3.709373  0.0143    0.7714       0.0857    0.00000  35 g (0.25 cup)
# 4     4.619986  0.1827    0.6346       0.1346    0.00000   52 g (0.5 cup)
#
#    nutrition-score-uk_100g
# 0                     14.0
# 1                      0.0
# ...

# %%
servings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169789 entries, 0 to 169788
# Data columns (total 11 columns):
# code                       169789 non-null float64
# product_name               169789 non-null object
# brands                     169789 non-null object
# origins                    169789 non-null object
# calories_pg                169789 non-null float64
# fat_pg                     169789 non-null float64
# carbs_pg                   169789 non-null float64
# proteins_pg                169789 non-null float64
# sodium_pg                  169789 non-null float64
# serving_size               169789 non-null object
# nutrition-score-uk_100g    169789 non-null float64
# dtypes: float64(7), object(4)
# memory usage: 14.2+ MB

# %%
servings[(servings['proteins_pg'] > 0.1) & 
         (servings.loc[:,'fat_pg'] <= 0.1) & 
         (servings.loc[:,'carbs_pg'] < 0.5)]
# Out:
#                 code                                       product_name  \
# 93      3.517000e+04                                      Liquid Aminos
# 95      3.528600e+04                                      Organic Shoyu
# 96      3.529300e+04                          Organic Wheat-Free Tamari
# 123     3.869000e+04                        Organic Regular Rolled Oats
# 210     1.816000e+03           Organic Flourless Sprouted 7-Grain Bread
# 211     1.975714e+08                                          Puppodums
# 333     8.506001e+08                                         Raw Shrimp
# 338     9.469091e+08                  Augason Farms, Vital Wheat Gluten
# 407     3.592700e+04                           Wild Alaskan Pink Salmon
# 411     3.840900e+04               Premium Chunk White Chicken In Broth
# 452     7.065080e+10                                    Red Curry Spice
# 457     7.222001e+10               Organic Nine Grain All Natural Bread
# ...
